# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Jaime Farina**<br>
# Desired Occupation: Data Science

# %% [markdown]
# *I am interested in data science because I like to program and analyze results, as well as optimize processes based on these analyzes*

# %% [markdown]
# ### My code will print the sum of odd numbers in the range 1 to 10 ###

# %%
t = 0
for i in range(1,11):
    if i%2:
        t += i
print(t)
# Out:
# 25

# %% [markdown]
# # Finally
# ---
# [Google](https://www.google.com)
# ---
# 1. Text 1
# 2. Text 2
# 3. Text 3
# ---
# > Be yourself; everyone else is already taken
